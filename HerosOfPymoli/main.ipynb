# %%
import pandas as pd

# %%
data_file = "Resources/purchase_data.csv"
data_file_df = pd.read_csv(data_file)
data_file_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
Number_of_Players = len(data_file_df["SN"].value_counts())
Total_Players = pd.DataFrame({"Total Players": [Number_of_Players]})
Total_Players
# Out:
#    Total Players
# 0            576

# %%
Unique_Items = len(data_file_df["Item ID"].unique())
Average_Purchase_Price = data_file_df["Price"].mean()
Total_Number_of_Purchases = data_file_df["Purchase ID"].count()
Total_Revenue = data_file_df["Price"].sum()
Totals_df = pd.DataFrame({"Number of Unique Items": [Unique_Items],
                       "Average Purchase Price": [Average_Purchase_Price],
                       "Total Number of Purchases": [Total_Number_of_Purchases],
                       "Total Number of Purchases": [Total_Number_of_Purchases], 
                       "Total Revenue": [Total_Revenue]})
                     
Totals_df.style.format({'Average Purchase Price':"${:,.2f}",
                         'Total Revenue': '${:,.2f}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_ed3091b4_7142_11ea_9721_f82fa8e1fe03" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of Unique Items</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Number of Purchases</th>        <th class="col_heading level0 col3" >Total Revenue</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ed3091b4_7142_11ea_9721_f82fa8e1fe03level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ed3091b4_7142_11ea_9721_f82fa8e1fe03row0_col0" class="data row0 col0" >183</td>
#                         <td id="T_ed3091b4_7142_11ea_9721_f82fa8e1fe03row0_col1" class="data row0 col1" >$3.05</td>
#                         <td id="T_ed3091b4_7142_11ea_9721_f82fa8e1fe03row0_col2" class="data row0 col2" >780</td>
# ...

# %%
data_file_df
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male      101
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %%
Gender_Grouped = data_file_df.groupby(["Gender"]).count()
Gender_Grouped

# Gender_Count = Gender_Grouped.unique()["SN"]

# Percentage_of_Players = Gender_Count / Number_of_Players * 100

# Gender_Demographics = pd.DataFrame({"Percentage of Players": Percentage_of_Players, 
#                                    "Total Count": Gender_Count})
# Out:
#                        Purchase ID   SN  Age  Item ID  Item Name  Price
# Gender
# Female                         113  113  113      113        113    113
# Male                           652  652  652      652        652    652
# Other / Non-Disclosed           15   15   15       15         15     15

# %%
gender_male_filter = data_file_df.loc[(data_file_df["Gender"] == "Male"),:]
gender_male_filter
# Out:
#      Purchase ID             SN  Age Gender  Item ID  \
# 0              0        Lisim78   20   Male      108
# 1              1    Lisovynya38   40   Male      143
# 2              2     Ithergue48   24   Male       92
# 3              3  Chamassasya86   24   Male      100
# 4              4      Iskosia90   23   Male      131
# ..           ...            ...  ...    ...      ...
# 774          774     Jiskjask80   11   Male      101
# 776          776         Iral74   21   Male      164
# 777          777     Yathecal72   20   Male       67
# 778          778        Sisur91    7   Male      101
# 779          779      Ennrian78   24   Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %%
gender_male_filter_unique = gender_male_filter["SN"].unique()
gender_male_filter_unique
# Out:
# array(['Lisim78', 'Lisovynya38', 'Ithergue48', 'Chamassasya86',
#        'Iskosia90', 'Yalae81', 'Itheria73', 'Iskjaskst81', 'Undjask33',
#        'Inguron55', 'Haisrisuir60', 'Saelaephos52', 'Assjaskan73',
#        'Saesrideu94', 'Lisirra25', 'Zontibe81', 'Chamalo71',
#        'Iathenudil29', 'Phiarithdeu40', 'Eyrian71', 'Siala43',
#        'Lisirra87', 'Lirtossa84', 'Eusri44', 'Aela59', 'Tyida79',
#        'Idai61', 'Farusrian86', 'Aeralria27', 'Haillyrgue51', 'Sondim73',
#        'Jeyciman68', 'Idaisuir85', 'Seuthep89', 'Sondilsaya62',
#        'Aerithriaphos45', 'Aidaillodeu39', 'Aelly27', 'Tyeosri53',
#        'Haerith37', 'Yasrisu92', 'Chanuchi25', 'Asur96', 'Iaralrgue74',
#        'Chanosia34', 'Aelin32', 'Ilosianya35', 'Zhisrisu83', 'Raesty92',
#        'Palyon91', 'Tyisur83', 'Yaliru88', 'Yadanu52', 'Jiskimya77',
#        'Yadaphos40', 'Alo38', 'Phaena87', 'Chamirraya83', 'Indonmol95',
#        'Jiskossa61', 'Pheodai94', 'Assistasda42', 'Lisosia93',
# ...

# %%
total_male_gamers = pd.Series(gender_male_filter_unique).count()
total_male_gamers
# Out:
# 484

# %%
total_gamers = total_male_gamers + total_famale_gamers + total_ond_gamers
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-50a9b599f8e9> in <module>
# ----> 1 total_gamers = total_male_gamers + total_famale_gamers + total_ond_gamers
#       2
#
# NameError: name 'total_famale_gamers' is not defined

# %%
gender_demographics = pd.DataFrame({"Total Count" : [total_male_gamers, total_female_gamers, total_ond_gamers], "Percentage_of_Players" : [percentage_male_gamers, percentage_female_gamers, percentage_ond_gamers]}, index = ["Male", "Female", "Other / Non-Disclosed"])
gender_demographics

    gender_demographics["Percentage_of_Players"] = gender_demographics["Percentage_of_Players"].map("{0:,.2%}".format)
gender_demographics
